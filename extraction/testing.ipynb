# %%
testing

# %%
import pandas as pd
import numpy as np

# %%
from openmeteo_apiclient import OpenMeteoApi
from import_cities import filter_by_country, load_cities_from_csv

client = OpenMeteoApi()
if not client.is_api_working():
        raise RuntimeError("OpenMeteo API is not working")
    
df = load_cities_from_csv("../data/bronze/worldcities.csv")
filtered_df = filter_by_country("Morocco", df)

print ("data filtered")


for index, city in filtered_df.iterrows():

        
    try:
        weather = client.get_data_from_this_city(
            latitude=str(city["lat"]),
            longitude=str(city["lng"]),
        )


        for index in  range(7):
            
            filtered_df.at[index, "forecast_date"] = day["time"][index]
            filtered_df.at[index, "temperature_max"] = day["temperature_2m_max"][index]
            filtered_df.at[index, "temperature_min"] = day["temperature_2m_min"][0index
            filtered_df.at[index, "precipitation_sum"] = day["precipitation_sum"][index]
            filtered_df.at[index, "precipitation_probability_max"] = day["precipitation_probability_max"][index]
            filtered_df.at[index, "wind_speed_10m_max"] = day["wind_speed_10m_max"][index]
            filtered_df.at[index, "wind_gusts_10m_max"] = day["wind_gusts_10m_max"][index]
            filtered_df.at[index, "weather_code"] = day["weather_code"][index]

    except Exception as e:
        print(f"Error fetching data for {city['city']}: {e}")

# %%
print(filtered_df.head(1))
